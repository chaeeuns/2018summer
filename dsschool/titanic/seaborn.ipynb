# %%
import pandas as pd

# %%
train = pd.read_csv("train.csv",index_col = "PassengerId")
train.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
test = pd.read_csv("test.csv",index_col = "PassengerId")
test.head()
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#               Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# PassengerId
# 892          34.5      0      0   330911   7.8292   NaN        Q
# 893          47.0      1      0   363272   7.0000   NaN        S
# 894          62.0      0      0   240276   9.6875   NaN        Q
# 895          27.0      0      0   315154   8.6625   NaN        S
# 896          22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# # Explore

# %%
# %matplotlib inline 
#화면에 결과가 바로 나옴
import seaborn as sns

# %% [markdown]
# ##  countplot

# %%
# hue : 지정된 칼럼의 결과를 기준으로 데이터를 쪼갠다. 
sns.countplot(data = train, x="Embarked", hue="Survived")

# %%
sns.countplot(data = train, x="Pclass", hue="Survived")

# %% [markdown]
# ## barplot

# %%
sns.barplot(data=train, x="Pclass", y="Fare", hue="Survived" )
# Pclass 에 따른 평균 운임요금을 보여줌
# 검정색 바가 길면 --> 표준 편차가 크다 !

# %%
# countplot(classification) vs barplot(regressin)
# 컬럼의 결과가 숫자컬럼 = barplot (countplot에 넣으면 경우의 수가 너무 많아짐)

# %% [markdown]
# ## pointplot

# %%
sns.pointplot(data=train, x="Pclass", y="Fare", hue="Survived" )

# %%
# x축 값들끼리 서로간의 연관 관계가 있으면 pointplot(ex.Hour) 없으면 barplot(ex.Embarked)

# %% [markdown]
# ## distplot

# %%
# train["Fare"] 에서 100~500은 outlier
low_fare = train[train["Fare"]<100]

Perish = low_fare[low_fare["Survived"] == 0]
Survived = low_fare[low_fare["Survived"] == 1]

sns.distplot(Perish["Fare"], hist=False, label="Perish")
sns.distplot(Survived["Fare"], hist=False, label="Survived")
# 운임요금의 분포

# %% [markdown]
# ## lmplot

# %%
low_fare = train[train["Fare"]<500]
sns.lmplot(data=low_fare, x="Age", y="Fare", hue="Survived", fit_reg = False)

# %% [markdown]
# ### subplot

# %%
import matplotlib.pyplot as plt

figure, ((ax1,ax2,ax3),(ax4,ax5,ax6)) = plt.subplots(nrows = 2, ncols = 3)
figure.set_size_inches(18,8)

sns.countplot(data=train, x="Embarked", hue="Survived", ax=ax1)
sns.countplot(data=train, x="Sex", hue="Survived", ax=ax2)
sns.countplot(data=train, x="Pclass", hue="Survived", ax=ax3)
sns.countplot(data=train, x="SibSp", hue="Survived", ax=ax4)
sns.countplot(data=train, x="Parch", hue="Survived", ax=ax5)
